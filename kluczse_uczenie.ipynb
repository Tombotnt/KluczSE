# %% [markdown]
# <a href="https://colab.research.google.com/github/Tombotnt/KluczSE/blob/main/kluczse_uczenie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Przygotowanie potrzebnych plików

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 15705 (delta 10), reused 17 (delta 6), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.50 MiB | 23.27 MiB/s, done.
# Resolving deltas: 100% (10755/10755), done.

# %%
# !mkdir -p /content/datasets/yolov5/data
# !cp -r drive/MyDrive/syseks/train_data /content/datasets/yolov5/data/train_data
# !cp drive/MyDrive/syseks/klucz.yaml ./yolov5/data

# %% [markdown]
# # Instalacja biblioteki ultralytics i załadowanie modelu (yolov5mu.pt lub yolov5nu.pt)

# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 26.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov5nu.pt')
# Out:
# ...
# 100%|██████████| 5.27M/5.27M [00:00<00:00, 69.8MB/s]

# %% [markdown]
# # Uczenie sieci z wykorzystaniem GPU

# %%
results = model.train(data='yolov5/data/klucz.yaml', epochs=50, device=0, batch=32)
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Dodatkowe komendy, aby wyeksportować wyniki na dysk google

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !cp -r /content/runs/detect/train/ /content/drive/MyDrive/syseks/outn/
